3 kB/s eta 0:00:09
#    ---------------------- ----------------- 1.3/2.3 MB 122.3 kB/s eta 0:00:09
#    ---------------------- ----------------- 1.3/2.3 MB 122.3 kB/s eta 0:00:09
#    ---------------------- ----------------- 1.3/2.3 MB 122.3 kB/s eta 0:00:09
#    ---------------------- ----------------- 1.3/2.3 MB 122.3 kB/s eta 0:00:09
#    ---------------------- ----------------- 1.3/2.3 MB 122.3 kB/s eta 0:00:09
#    ---------------------- ----------------- 1.3/2.3 MB 122.3 kB/s eta 0:00:09
#    ---------------------- ----------------- 1.3/2.3 MB 122.3 kB/s eta 0:00:09
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    -------------------------- ------------- 1.6/2.3 MB 130.7 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ------------------------------- -------- 1.8/2.3 MB 100.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.1/2.3 MB 85.0 kB/s eta 0:00:03
#    ---------------------------------------- 2.3/2.3 MB 75.0 kB/s  0:00:30
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ---------------------------------------- 0/6 [pyparsing]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    -------------------------- ------------- 4/6 [contourpy]
#    -------------------------- ------------- 4/6 [contourpy]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    ---------------------------------------- 6/6 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\shannu\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\shannu\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Matplotlib Version:", plt.matplotlib.__version__)
print("Scikit-learn Version:", sklearn.__version__)
# Out:
# NumPy Version: 2.4.2
# Pandas Version: 2.3.3
# Matplotlib Version: 3.11.1
# Scikit-learn Version: 1.9.0

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
a = np.array([10,20,30,40])
print(a)
# Out:
# [10 20 30 40]

# %%
import pandas as pd

data = {
    "Name": ["Ram","Sita","John"],
    "Age": [20,21,22]
}

df = pd.DataFrame(data)
df
# Out:
#    Name  Age
# 0   Ram   20
# 1  Sita   21
# 2  John   22

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,30,40]

plt.plot(x,y)
plt.show()

# %%
b="KLH BOWRAMPET"
a="hi"
print(b[2:5])
print(b)
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(b.capitalize())
print(b.casefold())
print(b.center(60,'*'))
print(b.count("A"))
print(b.find("KLH"))
print(b.index("BOWRAMPET"))
print(b.islower())
print(b.isupper())
print("-".join(b))
print(b.lower())
print(b.replace("KLH","KLB"))
print(b.swapcase())
print(b.title())
print(b.upper())
print(b.zfill(50))
print(a+" "+b)
# Out:
# H B
# KLH BOWRAMPET
# KLH B
# H BOWRAMPET
# AMP
# Klh bowrampet
# klh bowrampet
# ***********************KLH BOWRAMPET************************
# 1
# 0
# 4
# False
# True
# K-L-H- -B-O-W-R-A-M-P-E-T
# klh bowrampet
# KLB BOWRAMPET
# klh bowrampet
# Klh Bowrampet
# KLH BOWRAMPET
# 0000000000000000000000000000000000000KLH BOWRAMPET
# hi KLH BOWRAMPET

# %%
a="name {fname},{age}".format(fname="john",age="19")
b="name {0},{1}".format("john",19)
c="name {},{}".format("john",19)
d="Johnnn"
print(a)
print(b)
print(c)
# Out:
# name john,19
# name john,19
# name john,19
